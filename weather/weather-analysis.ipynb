# %% [markdown]
# # Weather Analysis Project

# %% [markdown]
# # 1. Find all the unique 'Wind Speed' values in the data.

# %%
import pandas as pd

# get data from csv
weather = pd.read_csv('weather.csv')

# print the top 5 datas
print(weather.head())
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# get the unique values in the wind speed column
unique_wind_speed = weather['Wind Speed_km/h'].unique()

# sort the unique values
sorted_unique_wind_speed = sorted(unique_wind_speed)

# print the sorted unique values
print(sorted_unique_wind_speed)
# Out:
# [0, 2, 4, 6, 7, 9, 11, 13, 15, 17, 19, 20, 22, 24, 26, 28, 30, 32, 33, 35, 37, 39, 41, 43, 44, 46, 48, 50, 52, 54, 57, 63, 70, 83]

# %% [markdown]
# # 2. Find the number of times when 'Weather' shows 'Clear'

# %%
# get the counts of the unique values in the weather column
num_weather = weather['Weather'].value_counts()

# print the values of the key 'Clear'
print(num_clear['Clear'])
# Out:
# 1326

# %% [markdown]
# # 3. Find the number of times when 'Wind Speed' was exactly '4 km/h'

# %%
# get the counts of the unique values in the wind speed column
num_speed = weather['Wind Speed_km/h'].value_counts()

# print the values of the key 4
print(num_speed[4])
# Out:
# 474

# %% [markdown]
# # 4. Find out how many NULL values are in the data

# %%
# count all values that are null
weather.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# count all values that are not null
weather.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# # 5. Rename the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
weather.rename(columns={'Weather': 'Weather Condition'}, inplace=True)

# %% [markdown]
# # 6. Find the mean 'Visibility' value

# %%
weather['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # 7. What is the Standard Deviation of 'Pressure' in the data?

# %%
weather['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# # 8. What is the Variance of 'Relative Humidity' in this data?

# %%
weather['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# # 9. Find all instances when 'Snow' was recorded

# %%
snow_1 = weather[weather['Weather Condition'] == 'Snow']
print(snow_1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
snow_2 = weather[weather['Weather Condition'].str.contains('Snow')].tail(50)
print(snow_2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %%
snow_3 = weather[weather['Weather Condition'].str.contains('Snow')].head(50)
print(snow_3)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   1/2/2012 17:00    -2.1              -9.5         57               22
# 44   1/2/2012 20:00    -5.6             -13.4         54               24
# 45   1/2/2012 21:00    -5.8             -12.8         58               26
# 47   1/2/2012 23:00    -7.4             -14.1         59               17
# 48    1/3/2012 0:00    -9.0             -16.0         57               28
# 50    1/3/2012 2:00   -10.5             -15.8         65               22
# 51    1/3/2012 3:00   -11.3             -18.7         54               33
# 53    1/3/2012 5:00   -12.9             -19.1         60               22
# 54    1/3/2012 6:00   -13.3             -19.3         61               19
# 55    1/3/2012 7:00   -14.0             -19.5         63               19
# 84   1/4/2012 12:00   -13.7             -21.7         51               11
# 86   1/4/2012 14:00   -11.3             -19.0         53                7
# ...

# %% [markdown]
# # 10. Find all instances when 'Wind Speed' is above 24 and 'Visibility' is 25

# %%
filtered_wind_speed_visibility = weather[(weather['Wind Speed_km/h'] > 24) & (weather['Visibility_km'] == 25)]
print(filtered_wind_speed_visibility)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# # 11. What is the MEAN value of each column against each 'Weather Condition'?

# %%
weather.drop('Date/Time', axis=1).groupby('Weather Condition').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# # 12. What is the MINIMUM & MAXIMUM value of each column against each 'Weather Condition'?

# %%
min = weather.drop('Date/Time', axis=1).groupby('Weather Condition').min()
max = weather.drop('Date/Time', axis=1).groupby('Weather Condition').max()

# %%
min
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                                     -23.3             -28.5         20
# Cloudy                                    -21.4             -26.8         18
# Drizzle                                     1.1              -0.2         74
# Drizzle,Fog                                 0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                0.9               0.1         92
# Drizzle,Snow,Fog                            0.3              -0.1         92
# Fog                                       -16.0             -17.2         80
# Freezing Drizzle                           -9.0             -12.2         78
# Freezing Drizzle,Fog                       -6.4              -9.0         82
# Freezing Drizzle,Haze                      -5.8              -8.3         81
# ...

# %%
max
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# Freezing Drizzle,Haze                      -5.0              -7.7         83
# ...

# %% [markdown]
# # 13. Show all the records where 'Weather Condition' is 'Fog'

# %%
weather[weather['Weather Condition'].str.contains('Fog')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %% [markdown]
# # 14. Find all instances when 'Weather Condition' is 'Clear' or 'Visibility' is above 40

# %%
filtered_weather_visibility = weather[(weather['Weather Condition'] == 'Clear') & (weather['Visibility_km'] > 40)]

# %%
filtered_weather_visibility
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# 352    1/15/2012 16:00   -15.1             -22.8         52               24
# 425    1/18/2012 17:00   -11.3             -18.8         54               26
# 440     1/19/2012 8:00   -13.7             -18.4         68               19
# 441     1/19/2012 9:00   -12.7             -17.2         69               17
# ...                ...     ...               ...        ...              ...
# 8384   12/15/2012 8:00   -10.7             -15.6         67               13
# 8385   12/15/2012 9:00   -10.4             -15.9         64               19
# 8389  12/15/2012 13:00    -8.4             -14.7         60               19
# 8631  12/25/2012 15:00    -7.1             -13.7         59               17
# 8632  12/25/2012 16:00    -7.5             -13.9         60               11
#
# ...

# %% [markdown]
# # 15. Find all instances when 'Weather' is 'Clear' and 'Relative Humidity' is greater than 5 or 'Visibility' is greater than 4'

# %%
filtered_weather_humidity_visibility = weather[((weather['Weather Condition'] == 'Clear') & (weather['Rel Hum_%'] > 5)) | (weather['Visibility_km'] > 40)]
print(filtered_weather_humidity_visibility)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# # 16. Plot how the temperature changes with date and time

# %%
import matplotlib.pyplot as plt

weather['Date/Time'] = pd.to_datetime(weather['Date/Time'])
weather
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather Condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
fig, ax = plt.subplots()

ax.plot(weather['Date/Time'], weather['Temp_C'], color='b')
ax.set_xlabel("Date")
ax.set_ylabel("Temperature (Celcius)")
ax.set_title("The Change in Temperature over a Year")
# Out:
# Text(0.5, 1.0, 'The Change in Temperature over a Year')
